# %%
import pickle

query_path = '/dk/rag-dataset/queries/'
embedding_path = 'query-embedding-dpr_multi-nq-train-slim-20240429-9323ec.d9c57f476b7bb281a36612649b3c111f/embedding.pkl'
embedding_path = 'query-embedding-dpr_multi-nq-train-20240429-9323ec.fabc40f467c7f2262628ce1e135b0337/embedding.pkl'

with open(query_path + embedding_path, 'rb') as f:
    embeddings = pickle.load(f)

print("embedding length: ", embeddings['embedding'].shape)
first_vector = embeddings['embedding'][0]

print('vector length: ', first_vector.shape)
print("First vector: ", first_vector)
# Out:
# embedding length:  (79168,)
# vector length:  (768,)
# First vector:  [-3.58066373e-02  2.71035910e-01 -1.11217737e-01 -5.01318350e-02
#   2.85387814e-01  4.36339110e-01  4.39187497e-01 -1.32341668e-01
#  -1.13257699e-01  3.67516391e-02  4.16054130e-02  1.37873545e-01
#  -6.70737982e-01  1.33894235e-01  7.36285672e-02  3.12761158e-01
#  -2.40312457e-01 -4.68464077e-01  5.12784064e-01 -3.23519856e-01
#   3.96995336e-01  1.56265929e-01  1.35765478e-01 -1.92816645e-01
#  -3.69651169e-01  1.04708811e-02 -3.95161361e-01 -6.18679896e-02
#  -3.04980516e-01  1.82022661e-01 -2.82694489e-01 -3.79084758e-02
#   1.09600455e-01 -1.77086387e-02  1.98698178e-01  2.15542808e-01
#  -9.01607051e-02 -7.55452737e-02  5.18672109e-01  6.63974956e-02
#   8.38067457e-02  1.29487678e-01 -1.82688385e-01 -1.38263941e-01
#   1.32364151e-03  2.51734197e-01  4.25839126e-01 -4.94242013e-02
#   5.62857091e-01 -5.18723689e-02  1.78564012e-01 -1.27158165e-01
# ...
