# %%
import os
io_path = '/dk/lcj_rag/pyserini-autofusion/experiments/runs/'

depth=1000
#  alpha*bf + (1-alpha)*bm25
nq = -1
k=100

bf_trec_path = f'{io_path}/base_trec/run.dpr.wq-train.bm25.trec'
bm25_trec_path = f'{io_path}/base_trec/run.dpr.wq-train.multi.bf.trec'
fusion_tag = 'rrf'
out_trec_path = f'{io_path}/wq_train/run.dpr.wq-train.fusion.alpha-{fusion_tag}.nq-{nq}.k-{k}.trec'
out_json_path = f'{io_path}/wq_train/run.dpr.wq-train.fusion.alpha-{fusion_tag}.nq-{nq}.k-{k}.json'

# %%
cmd0 = f'python -m pyserini.autofusion \
        --runs {bf_trec_path} {bm25_trec_path} \
        --runtag {fusion_tag} \
        --method rrf  \
        --depth {depth}  \
        --nq {nq}  \
        --k {k} \
        --output {out_trec_path}'
# print(cmd0)
os.system(cmd0)
# Out:
# 0

# %%
cache_path = '/dk/lcj_rag/pyserini-autofusion/experiments/cache/'
cmd1 = f'python -m pyserini.eval.convert_trec_run_to_dpr_retrieval_run_on_cache \
  --index wikipedia-dpr-100w \
  --topics dpr-wq-train \
  --gt {cache_path}wq_train_bf_qid_gt_set.pkl {cache_path}wq_train_bm25_qid_gt_set.pkl \
  --input {out_trec_path} \
  --output {out_json_path}'
os.system(cmd1)
# Out:
# resultPath: /root/.cache/pyserini/topics-and-qrels/topics.dpr.wq.train.txt
# checking path: /dk/rag-dataset/indexes/lucene-index.wikipedia-dpr-100w.20210120.d1b9e6...
# Jun 30, 2024 2:05:24 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 100%|██████████| 377800/377800 [00:54<00:00, 6940.90it/s]
# 0

# %%
nq = -1
out_json_path = f'{io_path}/wq_train/run.dpr.wq-train.fusion.alpha-{fusion_tag}.nq-{nq}.k-{k}.json'
print(out_json_path)
cmd2 = f'python -m pyserini.eval.evaluate_dpr_retrieval \
  --retrieval {out_json_path} \
  --topk 100'
os.system(cmd2)
# Out:
# /dk/lcj_rag/pyserini-autofusion/experiments/runs//wq_train/run.dpr.wq-train.fusion.alpha-rrf.nq--1.k-100.json
#  96%|█████████▌| 3629/3778 [00:00<00:00, 18192.10it/s]
# qid: 0	Top100	has_answer: 0
# qid: 8	Top100	has_answer: 0
# qid: 9	Top100	has_answer: 0
# qid: 11	Top100	has_answer: 0
# qid: 24	Top100	has_answer: 0
# qid: 26	Top100	has_answer: 0
# qid: 30	Top100	has_answer: 0
# qid: 32	Top100	has_answer: 0
# qid: 38	Top100	has_answer: 0
# qid: 39	Top100	has_answer: 0
# qid: 58	Top100	has_answer: 0
# qid: 62	Top100	has_answer: 0
# qid: 82	Top100	has_answer: 0
# qid: 94	Top100	has_answer: 0
# qid: 99	Top100	has_answer: 0
# qid: 107	Top100	has_answer: 0
# qid: 118	Top100	has_answer: 0
# qid: 123	Top100	has_answer: 0
# qid: 128	Top100	has_answer: 0
# qid: 132	Top100	has_answer: 0
# qid: 146	Top100	has_answer: 0
# qid: 147	Top100	has_answer: 0
# qid: 149	Top100	has_answer: 0
# qid: 150	Top100	has_answer: 0
# qid: 154	Top100	has_answer: 0
# qid: 173	Top100	has_answer: 0
# ...
