# %%
import numpy as np
from tqdm import tqdm
import os

io_path = '/dk/lcj_rag/pyserini-autofusion/experiments/runs'

depth=1000
#  alpha*bf + (1-alpha)*bm25
alpha = 0.5
nq = -1
k=100

bf_trec_path = f'{io_path}/base_trec/run.dpr.nq-train.bm25.trec'
bm25_trec_path = f'{io_path}/base_trec/run.dpr.nq-train.multi.bf.trec'
cache_path = '/dk/lcj_rag/pyserini-autofusion/experiments/cache/'
fusion_tag = 'fusion'

# %%
# for alpha in tqdm([0, 0.5, 1.00]):
for alpha in tqdm([0, 1.00]):
#     alpha = round(alpha, 2)
    alpha = f'{alpha:.1f}'
    print(alpha)
    train_out_trec_path = f'{io_path}/nq_train/run.dpr.nq-train.{fusion_tag}.alpha-{alpha}.nq-{nq}.k-{k}.trec'
    train_out_json_path = f'{io_path}/nq_train/run.dpr.nq-train.{fusion_tag}.alpha-{alpha}.nq-{nq}.k-{k}.json'
    cmd0 = f'python -m pyserini.autofusion \
            --runs {bf_trec_path} {bm25_trec_path} \
            --runtag {fusion_tag} \
            --method interpolation  \
            --alpha {alpha} \
            --depth {depth}  \
            --nq {nq}  \
            --k {k} \
            --output {train_out_trec_path}'
    # print(cmd0)
    os.system(cmd0)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0
# num_queries: 79168000
#  50%|█████     | 1/2 [1:07:17<1:07:17, 4037.12s/it]
# 1.0
# num_queries: 79168000
# 100%|██████████| 2/2 [2:13:50<00:00, 4015.32s/it]

# %%
nq = -1
# for alpha in tqdm([0]):
for alpha in tqdm([0, 1.00]):
    # alpha = round(alpha, 2)
    alpha = f'{alpha:.1f}'
    # alphafile = f'/dk/lcj_rag/pyserini-autofusion/experiments/runs/nq_train/alpha-{alpha}.csv'
    train_out_trec_path = f'{io_path}/nq_train/run.dpr.nq-train.{fusion_tag}.alpha-{alpha}.nq-{nq}.k-{k}.trec'
    train_out_json_path = f'{io_path}/nq_train/run.dpr.nq-train.{fusion_tag}.alpha-{alpha}.nq-{nq}.k-{k}.json'
    # cmd0 = f'python -m pyserini.autofusion \
    #         --runs {bf_trec_path} {bm25_trec_path} \
    #         --runtag {fusion_tag}-custom \
    #         --method custom  \
    #         --alphafile {alphafile} \
    #         --depth {depth}  \
    #         --nq {nq}  \
    #         --k {k} \
    #         --output {train_out_trec_path}'
    # # print(cmd0)
    # os.system(cmd0)

    # cmd1 = f'python -m pyserini.eval.convert_trec_run_to_dpr_retrieval_run \
    #     --index wikipedia-dpr-100w \
    #     --topics dpr-nq-train \
    #     --input {train_out_trec_path} \
    #     --output {train_out_json_path}'
    # os.system(cmd1)

    cache_path = '/dk/lcj_rag/pyserini-autofusion/experiments/cache/'
    cmd1 = f'python -m pyserini.eval.convert_trec_run_to_dpr_retrieval_run_on_cache \
    --index wikipedia-dpr-100w \
    --topics dpr-nq-train \
    --gt {cache_path}nq_train_bf_qid_gt_set.pkl {cache_path}nq_train_bm25_qid_gt_set.pkl \
    --input {train_out_trec_path} \
    --output {train_out_json_path}'
    os.system(cmd1)

# %%
filename = f'{io_path}/nq_train/run.dpr.nq-train.{fusion_tag}.all-alpha.nq-{nq}.k-{k}.res.test'
train_out_json_path = f'{io_path}/nq_train/run.dpr.nq-train.{fusion_tag}.alpha-?.nq-{nq}.k-{k}.json'

cmd2 = f'python -m pyserini.eval.evaluate_dpr_retrieval_all_alpha \
    --retrieval {train_out_json_path} \
    --topk 100  \
        --traindata False'
res = os.system(cmd2 + f'1> {filename}')
print(filename)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 1798it [00:00, 17977.45it/s]
# 3607it [00:00, 18041.13it/s]
# 5417it [00:00, 18063.40it/s]
# 7230it [00:00, 18087.09it/s]
# 9039it [00:00, 17866.02it/s]
# 10851it [00:00, 17951.22it/s]
# 12654it [00:00, 17976.07it/s]
# 14456it [00:00, 17989.12it/s]
# 16264it [00:00, 18014.81it/s]
# 18079it [00:01, 18053.46it/s]
# 19894it [00:01, 18081.28it/s]
# 21709it [00:01, 18100.17it/s]
# 23525it [00:01, 18115.69it/s]
# 25343it [00:01, 18132.48it/s]
# 27157it [00:01, 17910.10it/s]
# 28974it [00:01, 17986.89it/s]
# 30796it [00:01, 18054.50it/s]
# 32622it [00:01, 18114.68it/s]
# 34443it [00:01, 18142.13it/s]
# 36268it [00:02, 18172.92it/s]
# 38093it [00:02, 18195.83it/s]
# 39916it [00:02, 18202.95it/s]
# 41737it [00:02, 18202.29it/s]
# 43558it [00:02, 18199.45it/s]
# 45378it [00:02, 17949.65it/s]
# 47174it [00:02, 16800.81it/s]
# 48869it [00:02, 16257.36it/s]
# 50507it [00:02, 15897.95it/s]
# 52105it [00:02, 15657.04it/s]
# 53676it [00:03, 15472.70it/s]
# 55227it [00:03, 15344.80it/s]
# 56887it [00:03, 15706.15it/s]
# 58709it [00:03, 16437.03it/s]
# 60525it [00:03, 16941.36it/s]
# 62342it [00:03, 17304.47it/s]
# 64089it [00:03, 17351.34it/s]
# 65908it [00:03, 17598.86it/s]
# 67729it [00:03, 17780.07it/s]
# 69549it [00:03, 17903.24it/s]
# 71368it [00:04, 17986.99it/s]
# 73188it [00:04, 18047.80it/s]
# 75003it [00:04, 18077.30it/s]
# 76820it [00:04, 18102.80it/s]
# 79168it [00:04, 17507.18it/s]
#  33%|███▎      | 1/3 [00:34<01:08, 34.01s/it]
# 0it [00:00, ?it/s]
# 1769it [00:00, 17680.49it/s]
# 3561it [00:00, 17815.64it/s]
# 5349it [00:00, 17843.47it/s]
# 7138it [00:00, 17860.01it/s]
# 8925it [00:00, 17618.75it/s]
# 10715it [00:00, 17710.47it/s]
# 12487it [00:00, 17549.46it/s]
# 14292it [00:00, 17704.87it/s]
# 16103it [00:00, 17830.29it/s]
# 17925it [00:01, 17949.72it/s]
# 19737it [00:01, 17999.40it/s]
# 21549it [00:01, 18035.19it/s]
# 23364it [00:01, 18067.19it/s]
# 25182it [00:01, 18101.03it/s]
# 27008it [00:01, 18146.35it/s]
# 28834it [00:01, 18178.09it/s]
# 30654it [00:01, 18182.66it/s]
# 32473it [00:01, 17963.22it/s]
# 34295it [00:01, 18038.97it/s]
# 36112it [00:02, 18075.35it/s]
# 37931it [00:02, 18109.26it/s]
# 39755it [00:02, 18145.89it/s]
# 41570it [00:02, 17290.13it/s]
# 43308it [00:02, 16731.69it/s]
# 44990it [00:02, 16355.49it/s]
# 46632it [00:02, 16101.00it/s]
# 48247it [00:02, 15925.66it/s]
# 49843it [00:02, 15795.00it/s]
# 51424it [00:02, 15699.17it/s]
# 52995it [00:03, 15611.53it/s]
# 54557it [00:03, 15568.77it/s]
# 56300it [00:03, 16113.60it/s]
# 58119it [00:03, 16725.83it/s]
# 59934it [00:03, 17147.02it/s]
# 61748it [00:03, 17440.27it/s]
# 63563it [00:03, 17649.71it/s]
# 65377it [00:03, 17795.93it/s]
# 67194it [00:03, 17906.67it/s]
# 69008it [00:03, 17976.25it/s]
# 70824it [00:04, 18028.99it/s]
# 72642it [00:04, 18072.28it/s]
# 74461it [00:04, 18106.11it/s]
# 76281it [00:04, 18133.37it/s]
# 79168it [00:04, 17446.85it/s]
#  67%|██████▋   | 2/3 [01:16<00:38, 38.75s/it]
# 0it [00:00, ?it/s]
# 1774it [00:00, 17734.69it/s]
# 3585it [00:00, 17952.93it/s]
# 5397it [00:00, 18028.78it/s]
# 7216it [00:00, 18090.08it/s]
# 9035it [00:00, 18122.93it/s]
# 10863it [00:00, 18175.18it/s]
# 12692it [00:00, 18209.30it/s]
# 14515it [00:00, 18213.05it/s]
# 16339it [00:00, 18220.73it/s]
# 18166it [00:01, 18235.12it/s]
# 19990it [00:01, 18234.15it/s]
# 21814it [00:01, 18235.48it/s]
# 23640it [00:01, 18242.35it/s]
# 25467it [00:01, 18248.36it/s]
# 27292it [00:01, 18240.42it/s]
# 29117it [00:01, 18240.55it/s]
# 30942it [00:01, 18049.54it/s]
# 32769it [00:01, 18113.68it/s]
# 34592it [00:01, 18147.84it/s]
# 36420it [00:02, 18184.58it/s]
# 38246it [00:02, 18204.45it/s]
# 40070it [00:02, 18214.81it/s]
# 41897it [00:02, 18229.56it/s]
# 43727it [00:02, 18247.82it/s]
# 45554it [00:02, 18253.84it/s]
# 47383it [00:02, 18262.39it/s]
# 49210it [00:02, 18262.70it/s]
# 51037it [00:02, 18258.23it/s]
# 52866it [00:02, 18266.64it/s]
# 54700it [00:03, 18287.27it/s]
# 56529it [00:03, 18209.13it/s]
# 58350it [00:03, 17148.96it/s]
# 60078it [00:03, 16488.16it/s]
# 61739it [00:03, 16167.19it/s]
# 63364it [00:03, 15932.18it/s]
# 64963it [00:03, 15777.44it/s]
# 66545it [00:03, 15651.18it/s]
# 68113it [00:03, 15583.58it/s]
# 69673it [00:03, 15527.30it/s]
# 71448it [00:04, 16177.46it/s]
# 73286it [00:04, 16825.64it/s]
# 75115it [00:04, 17259.29it/s]
# 76954it [00:04, 17593.88it/s]
# 79168it [00:04, 17635.66it/s]
# 100%|██████████| 3/3 [01:53<00:00, 37.87s/it]
# /dk/lcj_rag/pyserini-autofusion/experiments/runs/nq_train/run.dpr.nq-train.fusion.all-alpha.nq--1.k-100.res.test
