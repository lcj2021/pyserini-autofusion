# %%
import os

# %%
import os
cmd0_slim = 'python -m pyserini.search.lucene \
    --index wikipedia-dpr-100w \
    --topics dpr-nq-train-slim \
    --output runs/run.dpr.nq-train-slim.bm25.trec \
    --threads 20 \
    --batch-size 80'
os.system(cmd0_slim)
# Out:
# resultPath: /root/.cache/pyserini/topics-and-qrels/topics.dpr.nq.train-slim.txt
# checking path: /dk/rag-dataset/indexes/lucene-index.wikipedia-dpr-100w.20210120.d1b9e6...
# Apr 29, 2024 12:32:33 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# Running dpr-nq-train-slim topics, saving to runs/run.dpr.nq-train-slim.bm25.trec...
# 100%|██████████| 1024/1024 [04:09<00:00,  4.10it/s]
# 0

# %%
cmd1_slim = 'python -m pyserini.eval.convert_trec_run_to_dpr_retrieval_run \
  --index wikipedia-dpr-100w \
  --topics dpr-nq-train-slim \
  --input runs/base_trec/run.dpr.nq-train-slim.bm25.trec \
  --output runs/base_trec/run.dpr.nq-train-slim.bm25.json'
os.system(cmd1_slim)
# Out:
# resultPath: /root/.cache/pyserini/topics-and-qrels/topics.dpr.nq.train-slim.txt
# checking path: /dk/rag-dataset/indexes/lucene-index.wikipedia-dpr-100w.20210120.d1b9e6...
# Apr 29, 2024 12:37:27 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 100%|██████████| 1024000/1024000 [11:12<00:00, 1521.81it/s]
# 0

# %%
cmd2_slim = 'python -m pyserini.eval.evaluate_dpr_retrieval \
  --retrieval runs/base_trec/run.dpr.nq-train-slim.bm25.json \
  --topk 20 100'
os.system(cmd2_slim)
# Out:
# 100%|██████████| 1024/1024 [00:00<00:00, 12997.72it/s]
# qid: 0	Top20	has_answer: 0
# qid: 0	Top100	has_answer: 0
# qid: 6	Top20	has_answer: 0
# qid: 6	Top100	has_answer: 0
# qid: 7	Top20	has_answer: 0
# qid: 7	Top100	has_answer: 0
# qid: 17	Top20	has_answer: 0
# qid: 17	Top100	has_answer: 0
# qid: 18	Top20	has_answer: 0
# qid: 18	Top100	has_answer: 0
# qid: 20	Top20	has_answer: 0
# qid: 20	Top100	has_answer: 0
# qid: 29	Top20	has_answer: 0
# qid: 29	Top100	has_answer: 0
# qid: 31	Top20	has_answer: 0
# qid: 31	Top100	has_answer: 0
# qid: 41	Top20	has_answer: 0
# qid: 41	Top100	has_answer: 0
# qid: 43	Top20	has_answer: 0
# qid: 43	Top100	has_answer: 0
# qid: 44	Top20	has_answer: 0
# qid: 44	Top100	has_answer: 0
# qid: 57	Top20	has_answer: 0
# qid: 57	Top100	has_answer: 0
# qid: 64	Top20	has_answer: 0
# qid: 64	Top100	has_answer: 0
# qid: 72	Top20	has_answer: 0
# qid: 72	Top100	has_answer: 0
# qid: 75	Top20	has_answer: 0
# qid: 75	Top100	has_answer: 0
# qid: 78	Top20	has_answer: 0
# ...
